# %%
print("hello, python")
# Out:
# hello, python

# %%
print("hello, multicampus")
# Out:
# hello, multicampus

# %% [markdown]
# # 제목1
# ## 제목2
# 오늘의 주제는
# 개발환경세팅이다.
#
# 줄을 바꾸고 싶다면,
# 윗줄 끝에 스페이스 두번을 넣어준다.
#
# - 소분류1
# * 소분류2
#
# **굵은글씨**
# *기울임*

# %%
# 주석처리 : 코드 셀에서 코드에 포함되지 않는 부분
print("hello, DS") # 출력 예시 코드
# Out:
# hello, DS

# %%
# 출력 예시 코드
print("Hello, yeoksam")
# Out:
# Hello, yeoksam

# %%
# 작성일자 : 2020.5.25
# 작성자 : 이원재
# 내용 : 출력 예시 코드
print("Hello, Friends")

# %%
a = 1

if a > 10:
    print('a는 10보다 크다') #1 
    print('a는 10보다 크다') #1 
    print('a는 10보다 크다') #1 
else: #그렇지않다면
    print('a는 10보다 작거나 같다') #2
# Out:
#   File "<ipython-input-3-a8f0db29dc3b>", line 5
#     print('a는 10보다 크다') #1
#                            ^
# IndentationError: unindent does not match any outer indentation level
